# %%
import sys
sys.path.insert(1, '/Users/christineegan/AppleM1SentimentAnalysis/src')

import general_functions
import twitter_api
import reddit_api
import process_data
import eda_visualizations
import word_vector_functions
import model_functions

    
if __name__ == '__main__':
    
    general_functions.create_banner('Social Media Opinion Mining App')
    
    platforms = {'1': 'Twitter', '2': 'Reddit'}
    print('')
    print('Choose a platform: ')
    print(platforms)
    platform = input()

    # choose a platform
    while platform not in list(platforms.keys()):
        print('\nInput not recognized. Try again.')
        platform = input()

    if platform == '1':
        general_functions.create_banner('Retrieve Tweets with Twython')
        answers = ['Y', 'N']
        print('\nWould you like to execute a schedule?', answers)
        answer = input()
        
        while answer.upper() not in answers:
            print('\nInput not recognized. Try again.')
            answer = input()
            
        if answer.upper == answers[0]:
            print('\n[*] Launching Schedule...')
            general_functions.execute_schedule('Twitter')
            print('\nWould you like to preprocess the data?', answers)
            answer = input()
            
            while answer.upper() not in answers:
                print('\nInput not recognized. Try again.')
                answer = input()
                
            if answer.upper() == answers[0]:
                process_data.batch_and_process_data('Twitter')
                print('\[*] Processing Complete.')
#                 print('\n[*] Would you like to model the data?')
#                 answer = input()
                
#                 if answer.upper() == answers[0]:
#                     model_functions.execute_models()
                    
#                 else:
#                     print('\n[*] Session Ended.')
   
            elif answer.upper() == answers[1]:
                print('\n[*] Session Ended.')             

        else:
            q, result_type, count = twitter_api.tweet_params()
            query = twitter_api.tweet_query_summary(q, result_type, count)
            twitter_api.retrieve_tweets(query)
            
            print('\nWould you like to preprocess the data?', answers)
            answer = input()
            
            while answer.upper() not in answers:
                print('\nInput not recognized. Try again.')
                answer = input()
                
            if answer.upper() == answers[0]:
                process_data.batch_and_process_data('Twitter')
#                 print('\n[*] Would you like to model the data?', answers)
#                 answer = input()
                
#                 if answer.upper() == answers[0]:
#                     model_functions.execute_models()
                    
#                 else:
#                     print('\[*] Session Ended.')
                
            elif answer.upper() == answers[1]:
                print('\n[*] Session Ended.')

    elif platform == '2':
        general_functions.create_banner('Retrieve Reddit Submissions and Comments with PRAW')

        answers = ['Y', 'N']
        print('\nWould you like to execute a schedule?', answers)
        answer = input()
        
        while answer.upper() not in answers:
            print('\nInput not recognized. Try again.')
            answer = input()
            
        if answer.upper() == answers[0]:
            print('\n[*] Launching Schedule...')
            general_functions.execute_schedule('Reddit')
            print('\nWould you like to preprocess the data?', answers)
            answer = input()
            
            while answer.upper() not in answers:
                print('\nInput not recognized. Try again.')
                answer = input()
                
            if answer.upper() == answers[0]:
                process_data.batch_and_process_data('Reddit')
                print('\[*] Processing Complete.')
#                 print('\n[*] Would you like to model the data?', answers)
#                 answer = input()
                
#                 if answer.upper() == answers[0]:
#                     model_functions.execute_models()
                    
#                 else:
#                     print('\[*] Session Ended.')
                
            elif answer.upper() == answers[1]:
                print('\n[*] Session Ended.')

        # conduct one session
        else:
            term, limit, subreds = submissions_params()
            query = reddit_query_summary(term, limit, subreds)
            retrieve_submissions(query)

            print('\nWould you like to preprocess the data?', answers)
            answer = input()
            
            while answer.upper() not in answers:
                print('\nInput not recognized. Try again.')
                answer = input()
                
            if answer.upper() == answers[0]:
                process_data.batch_and_process_data('Reddit')
                print('\[*] Processing Complete.')
#                 print('\n[*] Would you like to model the data?', answers)
#                 answer = input()
                
#                 if answer.upper() == answers[0]:
#                     model_functions.execute_models()
                    
#                 else:
#                     print('\[*] Session Ended.')
                
            elif answer.upper() == answers[1]:
                print('\n[*] Session Ended.')
# Out:
# Version 7.1.0 of praw is outdated. Version 7.1.2 was released 6 hours ago.

# %%
model_functions.execute_models()
# Out:
# ====================================================================================================
# Deploy a Model
# ----------------------------------------------------------------------------------------------------
# Enter a file name.
# /Users/christineegan/AppleM1SentimentAnalysis/data/tweet_data/labeled_data/2021-02-03_14_24_41.csv
#
# [*] Importing model data...
#
# ====================================================================================================
# Vectorize Text with Doc2Vec
# ----------------------------------------------------------------------------------------------------
#
# [*] Creating vocabulary...
#
# [*] Importing GLOVE...
#
# [*] Tagging Documents
#
# [*] Creating model...
#
# [*] Obtaining word vectors...
#
# [*] Processing word vectors from text...
#
# [*] Preparing data for model...
#
#  Choose a model:
# {'1': 'Logistic Regression', '2': 'GaussianNB', '3': 'SVC'}
#
#  To choose more than one model, enter each choice seperated by a comma.
# 1
#
# Enter you target (y) feature.
# polarity
#
# ====================================================================================================
# Class Distribution
# ----------------------------------------------------------------------------------------------------
# [*] Reviewing target data...
#    polarity  frequency  percent_of_data
# 0       1.0        406             81.2
# 1      -1.0         94             18.8
# ====================================================================================================
# Model Results
# ----------------------------------------------------------------------------------------------------
# Test Size:  0.2
# [*] Generating basic model with TTS for: LogisticRegression() ...
#      lens  subjectivity     com  JJS  JJ  NN  VBD  NNS  VB  RB  ...  RBS  PRP  \
# 249   101      0.843750  0.3612    0   2   5    0    0   0   0  ...    0    0
# 433    94      0.650000  0.3182    0   1   5    0    0   1   0  ...    0    0
# 19     29      0.800000  0.5106    0   1   3    0    0   0   0  ...    0    0
# 322    90      0.000000  0.4019    0   0   5    0    2   0   0  ...    0    0
# 332    94      0.650000  0.3182    0   1   5    0    0   1   0  ...    0    0
# ..    ...           ...     ...  ...  ..  ..  ...  ...  ..  ..  ...  ...  ...
# 106    79      0.000000 -0.5574    0   0   2    1    0   0   2  ...    0    0
# 270    51      0.377273  0.4215    0   1   3    0    0   0   1  ...    0    0
# 348    97      0.000000  0.4019    0   3   8    0    0   0   0  ...    0    0
# 435    94      0.650000  0.3182    0   1   6    0    0   1   0  ...    0    0
# 102   106      1.000000  0.6369    0   3   4    0    0   1   0  ...    0    0
#
#      NNP  WRB  RP  WP  WDT                                                vex  \
# 249    0    0   0   0    0  [-0.016055977, 0.023808852, -0.047484286, 0.00...
# 433    0    0   0   0    0  [-0.0034265376, 0.002822139, -0.0011727163, -0...
# 19     0    0   0   0    0  [-0.027738454, 0.030302113, -0.059221774, 0.01...
# 322    0    0   0   0    0  [0.003951547, -0.0025069735, -0.002056651, 0.0...
# 332    0    0   0   0    0  [-0.0034265376, 0.002822139, -0.0011727163, -0...
# ..   ...  ...  ..  ..  ...                                                ...
# 106    0    0   0   0    0  [-0.0022719963, 0.0049629663, 0.0026301015, 0....
# 270    0    0   0   0    0  [-0.00028377716, -8.290236e-05, -0.002089006, ...
# 348    0    0   0   0    0  [0.0006092301, 0.0018350235, 0.0013773781, -0....
# 435    0    0   0   0    0  [0.0011701854, -0.0027419778, 0.0042536566, 8....
# 102    0    0   0   0    0  [-0.00040530055, -0.003980296, -0.0031659917, ...
#
#      word  frequency
# 249     0          0
# 433     0          0
# 19      0          0
# 322     0          0
# 332     0          0
# ..    ...        ...
# 106     0          0
# 270     0          0
# 348     0          0
# 435     0          0
# 102     0          0
#
# [400 rows x 34 columns]
#      lens  subjectivity     com  JJS  JJ  NN  VBD  NNS  VB  RB  ...  RBS  PRP  \
# 361   109      0.000000  0.4019    0   2   6    0    1   0   0  ...    0    0
# 73     29      0.800000  0.5106    0   1   3    0    0   0   0  ...    0    0
# 374    76      0.527273  0.4404    0   2   2    0    1   0   0  ...    0    0
# 155    64      0.375000  0.5423    0   0   3    0    0   0   0  ...    0    0
# 104    62      0.800000  0.7579    0   2   2    0    1   0   0  ...    0    0
# ..    ...           ...     ...  ...  ..  ..  ...  ...  ..  ..  ...  ...  ...
# 347    84      0.454545  0.4215    0   0   3    0    0   0   0  ...    0    0
# 86     89      0.475000 -0.3400    0   3   2    0    0   0   1  ...    0    0
# 75    101      0.366667  0.2732    0   3   4    0    0   2   3  ...    0    0
# 438   102      0.694444 -0.2411    0   1   3    0    0   1   1  ...    0    0
# 15     86      0.000000  0.6597    0   0   6    0    0   0   0  ...    0    0
#
#      NNP  WRB  RP  WP  WDT                                                vex  \
# 361    0    0   0   0    0  [-0.0035036341, -0.0010285624, -0.0048486535, ...
# 73     0    0   0   0    0  [-0.01183318, 0.014559795, -0.026198538, 0.006...
# 374    0    0   0   0    0  [-0.0037392846, -0.0003365805, -0.002530431, -...
# 155    0    0   0   0    0  [-0.003783767, -0.0033385928, 0.0004139607, -0...
# 104    0    0   0   0    0  [-0.011261492, 0.015001908, -0.024609774, 0.00...
# ..   ...  ...  ..  ..  ...                                                ...
# 347    0    0   0   0    0  [0.004486924, 0.003417271, -0.0013258501, 0.00...
# 86     0    0   0   0    0  [0.0030610987, -0.00067909725, -0.0013393527, ...
# 75     0    0   0   0    0  [0.0019618042, -0.0039309235, -0.0036595913, 0...
# 438    0    0   0   0    0  [-0.0010162398, -0.0014889259, -0.0016241566, ...
# 15     0    0   0   0    0  [-0.0008359422, -0.0019532284, -0.002900756, -...
#
#      word  frequency
# 361     0          0
# 73      0          0
# 374     0          0
# 155     0          0
# 104     0          0
# ..    ...        ...
# 347     0          0
# 86      0          0
# 75      0          0
# 438     0          0
# 15      0          0
#
# [100 rows x 34 columns]
# 249    1.0
# 433    1.0
# 19     1.0
# 322    1.0
# 332    1.0
#       ...
# 106   -1.0
# 270    1.0
# 348    1.0
# 435    1.0
# 102    1.0
# Name: polarity, Length: 400, dtype: float64
# 361    1.0
# 73     1.0
# 374    1.0
# 155    1.0
# 104    1.0
#       ...
# 347    1.0
# 86    -1.0
# 75     1.0
# 438   -1.0
# 15     1.0
# Name: polarity, Length: 100, dtype: float64
# Test Size:  0.2
# [*] Generating basic model with TTS for: LogisticRegression() ...
#      lens  subjectivity     com  JJS  JJ  NN  VBD  NNS  VB  RB  ...  RBS  PRP  \
# 249   101      0.843750  0.3612    0   2   5    0    0   0   0  ...    0    0
# 433    94      0.650000  0.3182    0   1   5    0    0   1   0  ...    0    0
# 19     29      0.800000  0.5106    0   1   3    0    0   0   0  ...    0    0
# 322    90      0.000000  0.4019    0   0   5    0    2   0   0  ...    0    0
# 332    94      0.650000  0.3182    0   1   5    0    0   1   0  ...    0    0
# ..    ...           ...     ...  ...  ..  ..  ...  ...  ..  ..  ...  ...  ...
# 106    79      0.000000 -0.5574    0   0   2    1    0   0   2  ...    0    0
# 270    51      0.377273  0.4215    0   1   3    0    0   0   1  ...    0    0
# 348    97      0.000000  0.4019    0   3   8    0    0   0   0  ...    0    0
# 435    94      0.650000  0.3182    0   1   6    0    0   1   0  ...    0    0
# 102   106      1.000000  0.6369    0   3   4    0    0   1   0  ...    0    0
#
#      NNP  WRB  RP  WP  WDT                                                vex  \
# 249    0    0   0   0    0  [-0.016055977, 0.023808852, -0.047484286, 0.00...
# 433    0    0   0   0    0  [-0.0034265376, 0.002822139, -0.0011727163, -0...
# 19     0    0   0   0    0  [-0.027738454, 0.030302113, -0.059221774, 0.01...
# 322    0    0   0   0    0  [0.003951547, -0.0025069735, -0.002056651, 0.0...
# 332    0    0   0   0    0  [-0.0034265376, 0.002822139, -0.0011727163, -0...
# ..   ...  ...  ..  ..  ...                                                ...
# 106    0    0   0   0    0  [-0.0022719963, 0.0049629663, 0.0026301015, 0....
# 270    0    0   0   0    0  [-0.00028377716, -8.290236e-05, -0.002089006, ...
# 348    0    0   0   0    0  [0.0006092301, 0.0018350235, 0.0013773781, -0....
# 435    0    0   0   0    0  [0.0011701854, -0.0027419778, 0.0042536566, 8....
# 102    0    0   0   0    0  [-0.00040530055, -0.003980296, -0.0031659917, ...
#
#      word  frequency
# 249     0          0
# 433     0          0
# 19      0          0
# 322     0          0
# 332     0          0
# ..    ...        ...
# 106     0          0
# 270     0          0
# 348     0          0
# 435     0          0
# 102     0          0
#
# [400 rows x 34 columns]
#      lens  subjectivity     com  JJS  JJ  NN  VBD  NNS  VB  RB  ...  RBS  PRP  \
# 361   109      0.000000  0.4019    0   2   6    0    1   0   0  ...    0    0
# 73     29      0.800000  0.5106    0   1   3    0    0   0   0  ...    0    0
# 374    76      0.527273  0.4404    0   2   2    0    1   0   0  ...    0    0
# 155    64      0.375000  0.5423    0   0   3    0    0   0   0  ...    0    0
# 104    62      0.800000  0.7579    0   2   2    0    1   0   0  ...    0    0
# ..    ...           ...     ...  ...  ..  ..  ...  ...  ..  ..  ...  ...  ...
# 347    84      0.454545  0.4215    0   0   3    0    0   0   0  ...    0    0
# 86     89      0.475000 -0.3400    0   3   2    0    0   0   1  ...    0    0
# 75    101      0.366667  0.2732    0   3   4    0    0   2   3  ...    0    0
# 438   102      0.694444 -0.2411    0   1   3    0    0   1   1  ...    0    0
# 15     86      0.000000  0.6597    0   0   6    0    0   0   0  ...    0    0
#
#      NNP  WRB  RP  WP  WDT                                                vex  \
# 361    0    0   0   0    0  [-0.0035036341, -0.0010285624, -0.0048486535, ...
# 73     0    0   0   0    0  [-0.01183318, 0.014559795, -0.026198538, 0.006...
# 374    0    0   0   0    0  [-0.0037392846, -0.0003365805, -0.002530431, -...
# 155    0    0   0   0    0  [-0.003783767, -0.0033385928, 0.0004139607, -0...
# 104    0    0   0   0    0  [-0.011261492, 0.015001908, -0.024609774, 0.00...
# ..   ...  ...  ..  ..  ...                                                ...
# 347    0    0   0   0    0  [0.004486924, 0.003417271, -0.0013258501, 0.00...
# 86     0    0   0   0    0  [0.0030610987, -0.00067909725, -0.0013393527, ...
# 75     0    0   0   0    0  [0.0019618042, -0.0039309235, -0.0036595913, 0...
# 438    0    0   0   0    0  [-0.0010162398, -0.0014889259, -0.0016241566, ...
# 15     0    0   0   0    0  [-0.0008359422, -0.0019532284, -0.002900756, -...
#
#      word  frequency
# 361     0          0
# 73      0          0
# 374     0          0
# 155     0          0
# 104     0          0
# ..    ...        ...
# 347     0          0
# 86      0          0
# 75      0          0
# 438     0          0
# 15      0          0
#
# [100 rows x 34 columns]
# 249    1.0
# 433    1.0
# 19     1.0
# 322    1.0
# 332    1.0
#       ...
# 106   -1.0
# 270    1.0
# 348    1.0
# 435    1.0
# 102    1.0
# Name: polarity, Length: 400, dtype: float64
# 361    1.0
# 73     1.0
# 374    1.0
# 155    1.0
# 104    1.0
#       ...
# 347    1.0
# 86    -1.0
# 75     1.0
# 438   -1.0
# 15     1.0
# Name: polarity, Length: 100, dtype: float64
# Test Size:  0.3
# [*] Generating basic model with TTS for: LogisticRegression() ...
#      lens  subjectivity     com  JJS  JJ  NN  VBD  NNS  VB  RB  ...  RBS  PRP  \
# 5      67      0.000000  0.3612    0   0   1    0    0   0   1  ...    0    0
# 116   107      1.000000  0.3612    0   3   3    0    0   0   0  ...    0    0
# 45     99      0.500000  0.7096    0   3   4    1    0   0   0  ...    0    0
# 16     47      0.300000  0.6369    1   1   1    0    0   0   0  ...    0    0
# 462   105      0.750000  0.6705    0   2   4    0    0   1   2  ...    0    0
# ..    ...           ...     ...  ...  ..  ..  ...  ...  ..  ..  ...  ...  ...
# 106    79      0.000000 -0.5574    0   0   2    1    0   0   2  ...    0    0
# 270    51      0.377273  0.4215    0   1   3    0    0   0   1  ...    0    0
# 348    97      0.000000  0.4019    0   3   8    0    0   0   0  ...    0    0
# 435    94      0.650000  0.3182    0   1   6    0    0   1   0  ...    0    0
# 102   106      1.000000  0.6369    0   3   4    0    0   1   0  ...    0    0
#
#      NNP  WRB  RP  WP  WDT                                                vex  \
# 5      0    0   0   0    0  [-0.0031642835, -0.002385239, -0.004639911, 0....
# 116    2    0   0   0    0  [-0.0036575831, 0.0038796612, 0.0035137471, -0...
# 45     0    0   0   0    0  [-0.0042406074, 0.00030408453, -0.00043142476,...
# 16     0    0   0   0    0  [0.00040702958, -0.0031779837, 0.004756543, -0...
# 462    0    0   0   0    0  [0.0040680757, 0.0022890484, -0.0019699042, 0....
# ..   ...  ...  ..  ..  ...                                                ...
# 106    0    0   0   0    0  [-0.0022719963, 0.0049629663, 0.0026301015, 0....
# 270    0    0   0   0    0  [-0.00028377716, -8.290236e-05, -0.002089006, ...
# 348    0    0   0   0    0  [0.0006092301, 0.0018350235, 0.0013773781, -0....
# 435    0    0   0   0    0  [0.0011701854, -0.0027419778, 0.0042536566, 8....
# 102    0    0   0   0    0  [-0.00040530055, -0.003980296, -0.0031659917, ...
#
#      word  frequency
# 5       0          0
# 116     0          0
# 45      0          0
# 16      0          0
# 462     0          0
# ..    ...        ...
# 106     0          0
# 270     0          0
# 348     0          0
# 435     0          0
# 102     0          0
#
# [350 rows x 34 columns]
#      lens  subjectivity     com  JJS  JJ  NN  VBD  NNS  VB  RB  ...  RBS  PRP  \
# 361   109      0.000000  0.4019    0   2   6    0    1   0   0  ...    0    0
# 73     29      0.800000  0.5106    0   1   3    0    0   0   0  ...    0    0
# 374    76      0.527273  0.4404    0   2   2    0    1   0   0  ...    0    0
# 155    64      0.375000  0.5423    0   0   3    0    0   0   0  ...    0    0
# 104    62      0.800000  0.7579    0   2   2    0    1   0   0  ...    0    0
# ..    ...           ...     ...  ...  ..  ..  ...  ...  ..  ..  ...  ...  ...
# 266    32      0.800000  0.5106    0   1   3    0    0   0   0  ...    0    0
# 23     97      0.000000  0.4019    0   3   8    0    0   0   0  ...    0    0
# 222    99      0.710909  0.7902    0   1   7    0    0   0   0  ...    0    0
# 261   122      0.000000  0.5719    0   4   5    0    0   1   0  ...    0    0
# 426    62      0.000000  0.4019    0   0   3    0    1   2   0  ...    0    0
#
#      NNP  WRB  RP  WP  WDT                                                vex  \
# 361    0    0   0   0    0  [-0.0035036341, -0.0010285624, -0.0048486535, ...
# 73     0    0   0   0    0  [-0.01183318, 0.014559795, -0.026198538, 0.006...
# 374    0    0   0   0    0  [-0.0037392846, -0.0003365805, -0.002530431, -...
# 155    0    0   0   0    0  [-0.003783767, -0.0033385928, 0.0004139607, -0...
# 104    0    0   0   0    0  [-0.011261492, 0.015001908, -0.024609774, 0.00...
# ..   ...  ...  ..  ..  ...                                                ...
# 266    0    0   0   0    0  [-0.013646206, 0.016273052, -0.029898696, 0.00...
# 23     0    0   0   0    0  [0.0006092301, 0.0018350235, 0.0013773781, -0....
# 222    0    0   0   0    0  [-0.0033209024, -0.001032256, -0.004979948, -0...
# 261    0    0   0   0    0  [0.0020539581, -0.00024081997, 0.0047920733, 0...
# 426    0    0   0   0    0  [-0.0038748977, 0.00086433295, -0.00094234577,...
#
#      word  frequency
# 361     0          0
# 73      0          0
# 374     0          0
# 155     0          0
# 104     0          0
# ..    ...        ...
# 266     0          0
# 23      0          0
# 222     0          0
# 261     0          0
# 426     0          0
# [150 rows x 34 columns]
# 5      1.0
# 116    1.0
# 45     1.0
# 16     1.0
# 462    1.0
#       ...
# 106   -1.0
# 270    1.0
# 348    1.0
# 435    1.0
# 102    1.0
# Name: polarity, Length: 350, dtype: float64
# 361    1.0
# 73     1.0
# 374    1.0
# 155    1.0
# 104    1.0
#       ...
# 266    1.0
# 23     1.0
# 222    1.0
# 261    1.0
# 426    1.0
# Name: polarity, Length: 150, dtype: float64
# Test Size:  0.3
# [*] Generating basic model with TTS for: LogisticRegression() ...
#      lens  subjectivity     com  JJS  JJ  NN  VBD  NNS  VB  RB  ...  RBS  PRP  \
# 5      67      0.000000  0.3612    0   0   1    0    0   0   1  ...    0    0
# 116   107      1.000000  0.3612    0   3   3    0    0   0   0  ...    0    0
# 45     99      0.500000  0.7096    0   3   4    1    0   0   0  ...    0    0
# 16     47      0.300000  0.6369    1   1   1    0    0   0   0  ...    0    0
# 462   105      0.750000  0.6705    0   2   4    0    0   1   2  ...    0    0
# ..    ...           ...     ...  ...  ..  ..  ...  ...  ..  ..  ...  ...  ...
# 106    79      0.000000 -0.5574    0   0   2    1    0   0   2  ...    0    0
# 270    51      0.377273  0.4215    0   1   3    0    0   0   1  ...    0    0
# 348    97      0.000000  0.4019    0   3   8    0    0   0   0  ...    0    0
# 435    94      0.650000  0.3182    0   1   6    0    0   1   0  ...    0    0
# 102   106      1.000000  0.6369    0   3   4    0    0   1   0  ...    0    0
#
#      NNP  WRB  RP  WP  WDT                                                vex  \
# 5      0    0   0   0    0  [-0.0031642835, -0.002385239, -0.004639911, 0....
# 116    2    0   0   0    0  [-0.0036575831, 0.0038796612, 0.0035137471, -0...
# 45     0    0   0   0    0  [-0.0042406074, 0.00030408453, -0.00043142476,...
# 16     0    0   0   0    0  [0.00040702958, -0.0031779837, 0.004756543, -0...
# 462    0    0   0   0    0  [0.0040680757, 0.0022890484, -0.0019699042, 0....
# ..   ...  ...  ..  ..  ...                                                ...
# 106    0    0   0   0    0  [-0.0022719963, 0.0049629663, 0.0026301015, 0....
# 270    0    0   0   0    0  [-0.00028377716, -8.290236e-05, -0.002089006, ...
# 348    0    0   0   0    0  [0.0006092301, 0.0018350235, 0.0013773781, -0....
# 435    0    0   0   0    0  [0.0011701854, -0.0027419778, 0.0042536566, 8....
# 102    0    0   0   0    0  [-0.00040530055, -0.003980296, -0.0031659917, ...
#
#      word  frequency
# 5       0          0
# 116     0          0
# 45      0          0
# 16      0          0
# 462     0          0
# ..    ...        ...
# 106     0          0
# 270     0          0
# 348     0          0
# 435     0          0
# 102     0          0
#
# [350 rows x 34 columns]
#      lens  subjectivity     com  JJS  JJ  NN  VBD  NNS  VB  RB  ...  RBS  PRP  \
# 361   109      0.000000  0.4019    0   2   6    0    1   0   0  ...    0    0
# 73     29      0.800000  0.5106    0   1   3    0    0   0   0  ...    0    0
# 374    76      0.527273  0.4404    0   2   2    0    1   0   0  ...    0    0
# 155    64      0.375000  0.5423    0   0   3    0    0   0   0  ...    0    0
# 104    62      0.800000  0.7579    0   2   2    0    1   0   0  ...    0    0
# ..    ...           ...     ...  ...  ..  ..  ...  ...  ..  ..  ...  ...  ...
# 266    32      0.800000  0.5106    0   1   3    0    0   0   0  ...    0    0
# 23     97      0.000000  0.4019    0   3   8    0    0   0   0  ...    0    0
# 222    99      0.710909  0.7902    0   1   7    0    0   0   0  ...    0    0
# 261   122      0.000000  0.5719    0   4   5    0    0   1   0  ...    0    0
# 426    62      0.000000  0.4019    0   0   3    0    1   2   0  ...    0    0
#
#      NNP  WRB  RP  WP  WDT                                                vex  \
# 361    0    0   0   0    0  [-0.0035036341, -0.0010285624, -0.0048486535, ...
# 73     0    0   0   0    0  [-0.01183318, 0.014559795, -0.026198538, 0.006...
# 374    0    0   0   0    0  [-0.0037392846, -0.0003365805, -0.002530431, -...
# 155    0    0   0   0    0  [-0.003783767, -0.0033385928, 0.0004139607, -0...
# 104    0    0   0   0    0  [-0.011261492, 0.015001908, -0.024609774, 0.00...
# ..   ...  ...  ..  ..  ...                                                ...
# 266    0    0   0   0    0  [-0.013646206, 0.016273052, -0.029898696, 0.00...
# 23     0    0   0   0    0  [0.0006092301, 0.0018350235, 0.0013773781, -0....
# 222    0    0   0   0    0  [-0.0033209024, -0.001032256, -0.004979948, -0...
# 261    0    0   0   0    0  [0.0020539581, -0.00024081997, 0.0047920733, 0...
# 426    0    0   0   0    0  [-0.0038748977, 0.00086433295, -0.00094234577,...
#
#      word  frequency
# 361     0          0
# 73      0          0
# 374     0          0
# 155     0          0
# 104     0          0
# ..    ...        ...
# 266     0          0
# 23      0          0
# 222     0          0
# 261     0          0
# 426     0          0
#
# [150 rows x 34 columns]
# 5      1.0
# 116    1.0
# 45     1.0
# 16     1.0
# 462    1.0
#       ...
# 106   -1.0
# 270    1.0
# 348    1.0
# 435    1.0
# 102    1.0
# Name: polarity, Length: 350, dtype: float64
# 361    1.0
# 73     1.0
# 374    1.0
# 155    1.0
# 104    1.0
#       ...
# 266    1.0
# 23     1.0
# 222    1.0
# 261    1.0
# 426    1.0
# Name: polarity, Length: 150, dtype: float64
# Test Size:  0.4
# [*] Generating basic model with TTS for: LogisticRegression() ...
#      lens  subjectivity     com  JJS  JJ  NN  VBD  NNS  VB  RB  ...  RBS  PRP  \
# 467   106      1.000000  0.6369    0   3   4    0    0   1   0  ...    0    0
# 83     55      0.800000  0.5106    0   2   1    0    1   0   0  ...    0    0
# 245    70      0.418182  0.6369    1   0   4    0    1   0   0  ...    0    0
# 165    94      0.650000  0.3182    0   1   5    0    0   1   0  ...    0    0
# 163   110      1.000000  0.5023    0   1   4    0    0   1   1  ...    0    0
# ..    ...           ...     ...  ...  ..  ..  ...  ...  ..  ..  ...  ...  ...
# 106    79      0.000000 -0.5574    0   0   2    1    0   0   2  ...    0    0
# 270    51      0.377273  0.4215    0   1   3    0    0   0   1  ...    0    0
# 348    97      0.000000  0.4019    0   3   8    0    0   0   0  ...    0    0
# 435    94      0.650000  0.3182    0   1   6    0    0   1   0  ...    0    0
# 102   106      1.000000  0.6369    0   3   4    0    0   1   0  ...    0    0
#
#      NNP  WRB  RP  WP  WDT                                                vex  \
# 467    0    0   0   0    0  [-0.00040530055, -0.003980296, -0.0031659917, ...
# 83     0    0   0   0    0  [-0.0034907525, 0.0023939004, 0.0010325467, -0...
# 245    0    0   0   0    0  [0.00019286555, 0.0021764443, -0.00352854, 0.0...
# 165    0    0   0   0    0  [-0.0034265376, 0.002822139, -0.0011727163, -0...
# 163    0    0   0   0    0  [0.0014449256, -0.0037460462, 0.0049040266, -0...
# ..   ...  ...  ..  ..  ...                                                ...
# 106    0    0   0   0    0  [-0.0022719963, 0.0049629663, 0.0026301015, 0....
# 270    0    0   0   0    0  [-0.00028377716, -8.290236e-05, -0.002089006, ...
# 348    0    0   0   0    0  [0.0006092301, 0.0018350235, 0.0013773781, -0....
# 435    0    0   0   0    0  [0.0011701854, -0.0027419778, 0.0042536566, 8....
# 102    0    0   0   0    0  [-0.00040530055, -0.003980296, -0.0031659917, ...
#
#      word  frequency
# 467     0          0
# 83      0          0
# 245     0          0
# 165     0          0
# 163     0          0
# ..    ...        ...
# 106     0          0
# 270     0          0
# 348     0          0
# 435     0          0
# 102     0          0
#
# [300 rows x 34 columns]
#      lens  subjectivity     com  JJS  JJ  NN  VBD  NNS  VB  RB  ...  RBS  PRP  \
# 361   109      0.000000  0.4019    0   2   6    0    1   0   0  ...    0    0
# 73     29      0.800000  0.5106    0   1   3    0    0   0   0  ...    0    0
# 374    76      0.527273  0.4404    0   2   2    0    1   0   0  ...    0    0
# 155    64      0.375000  0.5423    0   0   3    0    0   0   0  ...    0    0
# 104    62      0.800000  0.7579    0   2   2    0    1   0   0  ...    0    0
# ..    ...           ...     ...  ...  ..  ..  ...  ...  ..  ..  ...  ...  ...
# 248    47      0.300000  0.6369    1   1   1    0    0   0   0  ...    0    0
# 145    53      0.650000  0.6369    1   1   3    1    0   0   0  ...    0    0
# 92     69      0.400000  0.6369    1   0   4    0    1   0   0  ...    0    0
# 152   120      0.520779 -0.3818    0   2  10    0    1   0   0  ...    0    0
# 367    53      0.650000  0.6369    1   1   3    1    0   0   0  ...    0    0
#
#      NNP  WRB  RP  WP  WDT                                                vex  \
# 361    0    0   0   0    0  [-0.0035036341, -0.0010285624, -0.0048486535, ...
# 73     0    0   0   0    0  [-0.01183318, 0.014559795, -0.026198538, 0.006...
# 374    0    0   0   0    0  [-0.0037392846, -0.0003365805, -0.002530431, -...
# 155    0    0   0   0    0  [-0.003783767, -0.0033385928, 0.0004139607, -0...
# 104    0    0   0   0    0  [-0.011261492, 0.015001908, -0.024609774, 0.00...
# ..   ...  ...  ..  ..  ...                                                ...
# 248    0    0   0   0    0  [0.00040702958, -0.0031779837, 0.004756543, -0...
# 145    0    0   0   0    0  [0.003538108, -0.000867754, 0.0004505563, -0.0...
# 92     0    0   0   0    0  [0.00019286555, 0.0021764443, -0.00352854, 0.0...
# 152    0    0   0   0    0  [-0.0032837063, -0.0025609673, -0.0011900086, ...
# 367    0    0   0   0    0  [0.003538108, -0.000867754, 0.0004505563, -0.0...
#
#      word  frequency
# 361     0          0
# 73      0          0
# 374     0          0
# 155     0          0
# 104     0          0
# ..    ...        ...
# 248     0          0
# 145     0          0
# 92      0          0
# 152     0          0
# 367     0          0
#
# [200 rows x 34 columns]
# 467    1.0
# 83     1.0
# 245    1.0
# 165    1.0
# 163    1.0
#       ...
# 106   -1.0
# 270    1.0
# 348    1.0
# 435    1.0
# 102    1.0
# Name: polarity, Length: 300, dtype: float64
# 361    1.0
# 73     1.0
# 374    1.0
# 155    1.0
# 104    1.0
#       ...
# 248    1.0
# 145    1.0
# 92     1.0
# 152   -1.0
# 367    1.0
# Name: polarity, Length: 200, dtype: float64
# Test Size:  0.4
# [*] Generating basic model with TTS for: LogisticRegression() ...
#      lens  subjectivity     com  JJS  JJ  NN  VBD  NNS  VB  RB  ...  RBS  PRP  \
# 467   106      1.000000  0.6369    0   3   4    0    0   1   0  ...    0    0
# 83     55      0.800000  0.5106    0   2   1    0    1   0   0  ...    0    0
# 245    70      0.418182  0.6369    1   0   4    0    1   0   0  ...    0    0
# 165    94      0.650000  0.3182    0   1   5    0    0   1   0  ...    0    0
# 163   110      1.000000  0.5023    0   1   4    0    0   1   1  ...    0    0
# ..    ...           ...     ...  ...  ..  ..  ...  ...  ..  ..  ...  ...  ...
# 106    79      0.000000 -0.5574    0   0   2    1    0   0   2  ...    0    0
# 270    51      0.377273  0.4215    0   1   3    0    0   0   1  ...    0    0
# 348    97      0.000000  0.4019    0   3   8    0    0   0   0  ...    0    0
# 435    94      0.650000  0.3182    0   1   6    0    0   1   0  ...    0    0
# 102   106      1.000000  0.6369    0   3   4    0    0   1   0  ...    0    0
#
#      NNP  WRB  RP  WP  WDT                                                vex  \
# 467    0    0   0   0    0  [-0.00040530055, -0.003980296, -0.0031659917, ...
# 83     0    0   0   0    0  [-0.0034907525, 0.0023939004, 0.0010325467, -0...
# 245    0    0   0   0    0  [0.00019286555, 0.0021764443, -0.00352854, 0.0...
# 165    0    0   0   0    0  [-0.0034265376, 0.002822139, -0.0011727163, -0...
# 163    0    0   0   0    0  [0.0014449256, -0.0037460462, 0.0049040266, -0...
# ..   ...  ...  ..  ..  ...                                                ...
# 106    0    0   0   0    0  [-0.0022719963, 0.0049629663, 0.0026301015, 0....
# 270    0    0   0   0    0  [-0.00028377716, -8.290236e-05, -0.002089006, ...
# 348    0    0   0   0    0  [0.0006092301, 0.0018350235, 0.0013773781, -0....
# 435    0    0   0   0    0  [0.0011701854, -0.0027419778, 0.0042536566, 8....
# 102    0    0   0   0    0  [-0.00040530055, -0.003980296, -0.0031659917, ...
#
#      word  frequency
# 467     0          0
# 83      0          0
# 245     0          0
# 165     0          0
# 163     0          0
# ..    ...        ...
# 106     0          0
# 270     0          0
# 348     0          0
# 435     0          0
# 102     0          0
#
# [300 rows x 34 columns]
#      lens  subjectivity     com  JJS  JJ  NN  VBD  NNS  VB  RB  ...  RBS  PRP  \
# 361   109      0.000000  0.4019    0   2   6    0    1   0   0  ...    0    0
# 73     29      0.800000  0.5106    0   1   3    0    0   0   0  ...    0    0
# 374    76      0.527273  0.4404    0   2   2    0    1   0   0  ...    0    0
# 155    64      0.375000  0.5423    0   0   3    0    0   0   0  ...    0    0
# 104    62      0.800000  0.7579    0   2   2    0    1   0   0  ...    0    0
# ..    ...           ...     ...  ...  ..  ..  ...  ...  ..  ..  ...  ...  ...
# 248    47      0.300000  0.6369    1   1   1    0    0   0   0  ...    0    0
# 145    53      0.650000  0.6369    1   1   3    1    0   0   0  ...    0    0
# 92     69      0.400000  0.6369    1   0   4    0    1   0   0  ...    0    0
# 152   120      0.520779 -0.3818    0   2  10    0    1   0   0  ...    0    0
# 367    53      0.650000  0.6369    1   1   3    1    0   0   0  ...    0    0
#
#      NNP  WRB  RP  WP  WDT                                                vex  \
# 361    0    0   0   0    0  [-0.0035036341, -0.0010285624, -0.0048486535, ...
# 73     0    0   0   0    0  [-0.01183318, 0.014559795, -0.026198538, 0.006...
# 374    0    0   0   0    0  [-0.0037392846, -0.0003365805, -0.002530431, -...
# 155    0    0   0   0    0  [-0.003783767, -0.0033385928, 0.0004139607, -0...
# 104    0    0   0   0    0  [-0.011261492, 0.015001908, -0.024609774, 0.00...
# ..   ...  ...  ..  ..  ...                                                ...
# 248    0    0   0   0    0  [0.00040702958, -0.0031779837, 0.004756543, -0...
# 145    0    0   0   0    0  [0.003538108, -0.000867754, 0.0004505563, -0.0...
# 92     0    0   0   0    0  [0.00019286555, 0.0021764443, -0.00352854, 0.0...
# 152    0    0   0   0    0  [-0.0032837063, -0.0025609673, -0.0011900086, ...
# 367    0    0   0   0    0  [0.003538108, -0.000867754, 0.0004505563, -0.0...
#
#      word  frequency
# 361     0          0
# 73      0          0
# 374     0          0
# 155     0          0
# 104     0          0
# ..    ...        ...
# 248     0          0
# 145     0          0
# 92      0          0
# 152     0          0
# 367     0          0
#
# [200 rows x 34 columns]
# 467    1.0
# 83     1.0
# 245    1.0
# 165    1.0
# 163    1.0
#       ...
# 106   -1.0
# 270    1.0
# 348    1.0
# 435    1.0
# 102    1.0
# Name: polarity, Length: 300, dtype: float64
# 361    1.0
# 73     1.0
# 374    1.0
# 155    1.0
# 104    1.0
#       ...
# 248    1.0
# 145    1.0
# 92     1.0
# 152   -1.0
# 367    1.0
# Name: polarity, Length: 200, dtype: float64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1adbd1922bd5> in <module>
# ----> 1 model_functions.execute_models()
#
# ~/AppleM1SentimentAnalysis/notebooks/program/app/final/src/model_functions.py in execute_models()
#     281     X = vectorized_data.drop('polarity', axis=1)
#     282     y = vectorized_data.polarity
# --> 283     model_results(models, X, y, use_smote)
#     284
#     285     print('\nSession Ended')
#
# ~/AppleM1SentimentAnalysis/notebooks/program/app/final/src/model_functions.py in model_results(clfs, X, y, use_smote)
#     226                                       random_state=42, shuffle=True)
#     227
# --> 228         clf_scores, clf_scores_mean = run_cross_val_model(clf, X, y, cv)
#     229         plot_my_cross_val_roc_curve(clf, X, y, cv, smote)
#     230
#
# ~/AppleM1SentimentAnalysis/notebooks/program/app/final/src/model_functions.py in run_cross_val_model(clf, X_test, y_test, cv)
#     145
#     146     scores = pd.DataFrame()
# --> 147     scores['Accuracy'] = model_selection.cross_val_score(clf, X, y, cv=cv,
#     148                                                        scoring='accuracy')
#     149     scores['AUC'] = model_selection.cross_val_score(clf, X, y, cv=cv,
#
# NameError: name 'X' is not defined

# %%
import pandas as pd
df = pd.read_csv('/Users/christineegan/AppleM1SentimentAnalysis/data/tweet_data/labeled_data/2021-02-03_14_24_41.csv')

# %%
df

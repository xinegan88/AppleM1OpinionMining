# %%
import sys
sys.path.insert(1, '/Users/christineegan/AppleM1SentimentAnalysis/src')

import general_functions
import twitter_api
import reddit_api
import process_data
import eda_visualizations
import word_vector_functions
import model_functions

    
if __name__ == '__main__':
    
    general_functions.create_banner('Social Media Opinion Mining App')
    
    platforms = {'1': 'Twitter', '2': 'Reddit'}
    print('')
    print('Choose a platform: ')
    print(platforms)
    platform = input()

    # choose a platform
    while platform not in list(platforms.keys()):
        print('\nInput not recognized. Try again.')
        platform = input()

    if platform == '1':
        general_functions.create_banner('Retrieve Tweets with Twython')
        answers = ['Y', 'N']
        print('\nWould you like to execute a schedule?', answers)
        answer = input()
        
        while answer.upper() not in answers:
            print('\nInput not recognized. Try again.')
            answer = input()
            
        if answer.upper == answers[0]:
            print('\n[*] Launching Schedule...')
            general_functions.execute_schedule('Twitter')
            print('\nWould you like to preprocess the data?', answers)
            answer = input()
            
            while answer.upper() not in answers:
                print('\nInput not recognized. Try again.')
                answer = input()
                
            if answer.upper() == answers[0]:
                process_data.batch_and_process_data('Twitter')
                print('\[*] Processing Complete.')
#                 print('\n[*] Would you like to model the data?')
#                 answer = input()
                
#                 if answer.upper() == answers[0]:
#                     model_functions.execute_models()
                    
#                 else:
#                     print('\n[*] Session Ended.')
   
            elif answer.upper() == answers[1]:
                print('\n[*] Session Ended.')             

        else:
            q, result_type, count = twitter_api.tweet_params()
            query = twitter_api.tweet_query_summary(q, result_type, count)
            twitter_api.retrieve_tweets(query)
            
            print('\nWould you like to preprocess the data?', answers)
            answer = input()
            
            while answer.upper() not in answers:
                print('\nInput not recognized. Try again.')
                answer = input()
                
            if answer.upper() == answers[0]:
                process_data.batch_and_process_data('Twitter')
#                 print('\n[*] Would you like to model the data?', answers)
#                 answer = input()
                
#                 if answer.upper() == answers[0]:
#                     model_functions.execute_models()
                    
#                 else:
#                     print('\[*] Session Ended.')
                
            elif answer.upper() == answers[1]:
                print('\n[*] Session Ended.')

    elif platform == '2':
        general_functions.create_banner('Retrieve Reddit Submissions and Comments with PRAW')

        answers = ['Y', 'N']
        print('\nWould you like to execute a schedule?', answers)
        answer = input()
        
        while answer.upper() not in answers:
            print('\nInput not recognized. Try again.')
            answer = input()
            
        if answer.upper() == answers[0]:
            print('\n[*] Launching Schedule...')
            general_functions.execute_schedule('Reddit')
            print('\nWould you like to preprocess the data?', answers)
            answer = input()
            
            while answer.upper() not in answers:
                print('\nInput not recognized. Try again.')
                answer = input()
                
            if answer.upper() == answers[0]:
                process_data.batch_and_process_data('Reddit')
                print('\[*] Processing Complete.')
#                 print('\n[*] Would you like to model the data?', answers)
#                 answer = input()
                
#                 if answer.upper() == answers[0]:
#                     model_functions.execute_models()
                    
#                 else:
#                     print('\[*] Session Ended.')
                
            elif answer.upper() == answers[1]:
                print('\n[*] Session Ended.')

        # conduct one session
        else:
            term, limit, subreds = submissions_params()
            query = reddit_query_summary(term, limit, subreds)
            retrieve_submissions(query)

            print('\nWould you like to preprocess the data?', answers)
            answer = input()
            
            while answer.upper() not in answers:
                print('\nInput not recognized. Try again.')
                answer = input()
                
            if answer.upper() == answers[0]:
                process_data.batch_and_process_data('Reddit')
                print('\[*] Processing Complete.')
#                 print('\n[*] Would you like to model the data?', answers)
#                 answer = input()
                
#                 if answer.upper() == answers[0]:
#                     model_functions.execute_models()
                    
#                 else:
#                     print('\[*] Session Ended.')
                
            elif answer.upper() == answers[1]:
                print('\n[*] Session Ended.')
# Out:
# Version 7.1.0 of praw is outdated. Version 7.1.2 was released 20 hours ago.
# ====================================================================================================
# Social Media Opinion Mining App
# ----------------------------------------------------------------------------------------------------
#
# Choose a platform:
# {'1': 'Twitter', '2': 'Reddit'}
# 1
#
# ====================================================================================================
# Retrieve Tweets with Twython
# ----------------------------------------------------------------------------------------------------
#
# Would you like to execute a schedule? ['Y', 'N']
# N
#
# Enter a search term.
# Apple M1
#
# Enter your result type:
# {'1': 'recent', '2': 'popular', '3': 'mixed'}
# 3
#
# Enter a result count:
# 100
#
#
# ====================================================================================================
# Summary of Query
# ----------------------------------------------------------------------------------------------------
# Check your responses carefully to avoid wasting API calls.
#
# ==============================
# Search term:  apple m1
# Result type:  mixed
# Number of results: 100
# ==============================
#
# Are you happy with your query? ['Y', 'N']
# Y
#
# [*] Generating Query...
#
# [*] Accessing credentials...
#
# [*] Obtaining authorization...
#
# [*] Filtering results...
#
# [*] Saving results to  ~/AppleM1SentimentAnalysis/data/tweet_data/raw_data/2021-02-04_11_57_40.csv
#
# Would you like to preprocess the data? ['Y', 'N']
# Y
#
# ====================================================================================================
# Preprocess Data
# ----------------------------------------------------------------------------------------------------
# [*] Retrieving session data from source directory...
#
# [*] Adding  2021-01-28_12_47_40.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-01_20_11_54.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_25.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_19.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_32_19.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_56_58.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_10_45.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_18.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_30_40.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-25_14_30_40.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_24.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_53_00.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_53_56.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_26.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_00_22.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_19_42.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_13_23.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-29_13_33_16.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_24_36.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_27.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_23.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_26_37.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_20_53_18.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_14_11_17.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_41_47.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_13_29_58.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_09_58_55.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_02_23.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_22.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_12_46.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_20_48_15.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-25_14_34_08.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_30_18.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_08.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_00_50_48.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_20.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_32_41.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_46_39.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_31_45.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_51_54.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_17_04_06.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_21.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_49_41.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_09.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_09_57_07.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_55_57.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_28_17.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_20_59_21.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_55_02.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_49_53.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_08_27.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-25_14_37_00.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_13_28_57.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_16_31.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_38_45.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_22_35.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_04_25.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_45_50.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_11_45.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_20_52_17.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_27_38.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_29_39.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_10_03_24.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_34_20.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_20_50_16.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_42_48.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_36_44.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_14_30.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-25_14_32_08.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_00_52_38.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_11_28.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_20_34.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_34_43.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_06_26.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_47_52.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_20_55_19.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_57_03.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_13_30_22.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_20_57_20.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_17_02_05.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_14_47.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_00_52_13.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_18_33.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_14_09_17.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_01_23.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_13_20_03.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_25_37.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_20_47_14.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_11_45.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_13_31_45.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-29_13_37_25.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_52_00.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-29_13_32_15.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_03_24.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_31_41.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_52_55.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_45_39.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_57_59.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-01_20_37_10.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_13_38_48.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_50_54.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_33_20.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_35_49.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_31_19.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_48_40.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-29_13_25_09.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_13_30.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-25_14_39_20.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-27_15_40_14.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_14_17_21.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_10_00_43.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_40_46.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_20_49_15.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_13_46.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_33_42.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_13_36_10.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_10.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_50_59.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_44_50.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-01_20_17_00.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-01_20_10_34.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_59_00.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_14_14_01.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_05_25.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_11.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_12_29.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_54_02.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_13.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_20_58_21.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_09_27.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_13_33_37.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-01_19_58_06.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_17_32.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_58_03.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_17_01_05.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_13_23_27.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_48_52.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-25_14_35_52.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_20_56_19.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_39_46.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_23_36.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_12.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_54_57.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-04_11_57_40.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_44_36.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_16.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_20_54_18.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_19_33.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_11_56_03.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_07_26.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_35_43.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-01_20_41_57.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_17.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_15.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_37_44.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_01_31.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_21_34.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-02-03_14_23_44.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_10_28.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_13_27_57.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_46_51.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_28_39.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_43_49.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_20_51_16.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_17_03_06.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_14.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-28_12_08_28.csv to batch:  2021-02-04_11_57_42.csv
# [*] Adding  2021-01-30_21_15_31.csv to batch:  2021-02-04_11_57_42.csv
#
# [*] Preprocessing batch: 2021-02-04_11_57_42.csv
#
# [*] Intiating text cleaning...
# -- Tokenizing...
# -- Removing non-alphabetic characters...
# -- Converting to lowercase...
# -- Removing hashtags, web addresses, and mentions...
# -- Removing any code tags...
# -- Joining tokens for further processing...
#
# [*] Labeling subjectivity...
# -- Calculating subjectivity scores...
#
# [*] Labeling polarity...
# -- Calculating polarity scores...
# -- Determining polarity label...
# Would you like to eliminate the neutral class? ['Y', 'N']
# Y
#
# [*] Processing text...
# -- Removing stopwords...
# -- Lemmatizing tokens...
#
# [*] Calculating text length...
#
# [*] Applying POS tags...
# -- Obtaining POS tags...
# -- Creating POS tag list...
# -- Counting POS tags...
#
# [*] Preprocessing Complete
#
# [*] Saving processed results to  /Users/christineegan/AppleM1SentimentAnalysis/data/tweet_data/labeled_data/2021-02-04_11_58_54.csv
